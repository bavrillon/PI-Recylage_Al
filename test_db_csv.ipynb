# %%
import numpy as np
import pandas as pd

# %%
df_currency = pd.read_csv('data/tables_csv/currency.csv', sep=';')
df_currency['USD'] = df_currency['USD'].replace(',', '.', regex=True).astype(float)
df_currency.set_index('name', inplace=True)
df_currency
# Out:
#        USD
# name
# EUR   1.08
# CHF   1.10
# USD   1.00
# GBP   1.36
# CNY   0.14

# %%
df_site = pd.read_csv('data/tables_csv/site.csv', sep=';')
df_site.set_index('site_code', inplace=True)
df_site
# Out:
#                name  premium_per_t currency
# site_code
# PAR           Paris            400      EUR
# GEN          Geneva            450      CHF
# NYC        New-York            650      USD

# %%
df_shape_type = pd.read_csv('data/tables_csv/shape_type.csv', sep=';')
df_shape_type.set_index('shape_type_id', inplace=True)
df_shape_type
# Out:
#                  name
# shape_type_id
# 0               swarf
# 1              offcut

# %%
df_composition = pd.read_csv('data/tables_csv/composition.csv', sep=';')
df_composition.set_index('composition_id', inplace=True)
df_composition
# Out:
#                      Si       Fe       Cu       Mn       Mg       Cr       Zn  \
# composition_id
# 1               0.00250  0.00400  0.00050  0.00050  0.00050  0.00050  0.00050
# 2               0.00950  0.00950  0.00100  0.00050  0.00050  0.00050  0.00100
# 3               0.00500  0.00500  0.04000  0.00500  0.01300  0.00100  0.00250
# 4               0.00600  0.00700  0.00100  0.01000  0.00100  0.00100  0.00100
# 5               0.00250  0.00400  0.00100  0.00100  0.02400  0.00200  0.00100
# 6               0.00400  0.00400  0.00100  0.00500  0.04500  0.00100  0.00250
# 7               0.00500  0.00700  0.00200  0.00150  0.01000  0.00200  0.00250
# 8               0.00300  0.00350  0.00100  0.00100  0.00600  0.00100  0.00100
# 9               0.00400  0.00500  0.01500  0.00300  0.02300  0.00200  0.06000
# 10              0.00600  0.00700  0.00100  0.00200  0.00050  0.00050  0.00100
# 11              0.00300  0.00700  0.00250  0.01300  0.01000  0.00050  0.00250
# ...

# %%
df_alloy = pd.read_csv('data/tables_csv/alloy.csv', sep=';')
df_alloy.set_index('alloy_id', inplace=True)
df_alloy
# Out:
#          site_code    name  composition_id
# alloy_id
# 1              PAR  AA1050               1
# 2              PAR  AA1100               2
# 3              GEN  AA2024               3
# 4              GEN  AA3003               4
# 5              NYC  AA5052               5
# 6              NYC  AA5083               6
# 7              PAR  AA6061               7
# 8              PAR  AA6063               8
# 9              PAR  AA7075               9
# 10             PAR  AA8011              10
# 11             PAR  AA3004              11
# 12             GEN  AA3105              12
# 13             GEN  AA5005              13
# 14             GEN  AA5050              14
# 15             GEN  AA5454              15
# 16             GEN  AA5754              16
# 17             NYC  AA6060              17
# 18             NYC  AA6066              18
# 19             NYC  AA7072              19
# 20             NYC  AA7178              20
# ...

# %%
df_raw_material = pd.read_csv('data/tables_csv/raw_material.csv', sep=';')
df_raw_material.set_index('raw_material_id', inplace=True)
df_raw_material
# Out:
#                   name  composition_id  cost_per_t  premium currency  \
# raw_material_id
# 1                   Si              25        2800        0      USD
# 2                   Fe              26         313        0      USD
# 3                  Cu               27        8750        0      USD
# 4                  Mn               28        2500        0      USD
# 5                  Mg               29        3200        0      USD
# 6                  Cr               30        9953        0      EUR
# 7                  Zn               31        2955        0      CNY
# 8                  Ti               32        4960        0      USD
# 9                P1020              33        2400        1      USD
# 10               P0202              34        2700        1      USD
#
#                  t_CO2_per_t
# raw_material_id
# 1                        1.0
# 2                        5.0
# 3                        0.5
# 4                        0.0
# ...

# %%
df_recycling_costs = pd.read_csv('data/tables_csv/recycling_costs.csv', sep=';')
df_recycling_costs.set_index('recycling_cost_id', inplace=True)
df_recycling_costs
# Out:
#                   site_code  shape_type_id  recycling_cost_per_t
# recycling_cost_id
# 1                       PAR              1                    56
# 2                       PAR              0                   400
# 3                       GEN              1                    40
# 4                       GEN              0                   500
# 5                       NYC              1                    80

# %%
df_scrap = pd.read_csv('data/tables_csv/scrap.csv', sep=';')
df_scrap.set_index('scrap_id', inplace=True)
df_scrap
# Out:
#          scrap_name  composition_id  shape_type_id  \
# scrap_id
# 1           scrap01              35              0
#
#           scrap_purchasing_cost_per_t  transportation_cost_per_t currency
# scrap_id
# 1                                1920                         50      EUR
